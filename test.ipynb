# %%
import src.database_utils_DRP as du

ok = du.test_connection(user_name="user1", user_passw="user1") 
print(ok)
# Out:
# Соединение установлено. PostgreSQL version: PostgreSQL 18.1 on x86_64-windows, compiled by msvc-19.44.35219, 64-bit
# True

# %%
import src.database_utils_DRP as du

ok = du.test_connection(user_name="user1", user_passw="user1") 
print(ok)

# %%
 pip install -r requirements.txt

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\guliv\AppData\Local\Programs\Python\Python312\python.exe

# %%
.\.venv\Scripts\python -m ipykernel install --user --name notes-venv
# Out:
#   Cell In[7], line 1
#     .\.venv\Scripts\python -m ipykernel install --user --name notes-venv
#     ^
# SyntaxError: invalid syntax
